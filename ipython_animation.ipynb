# %% [markdown]
# # Animation with <code>ipythonblocks</code>

# %% [markdown]
# For more on `ipythonblocks` see the home page at [https://github.com/jiffyclub/ipythonblocks](https://github.com/jiffyclub/ipythonblocks).

# %%
from ipythonblocks import BlockGrid

# %%
import time
from IPython.display import clear_output

# %% [markdown]
# It's possible to do animation of sorts using IPython's `clear_output` function.

# %%
grid = BlockGrid(3, 3)

previous_block = None

for block in grid:
    clear_output()
    block.green = 255
    
    if previous_block:
        previous_block.green = 0
    
    grid.show()
    
    previous_block = block
    
    time.sleep(0.2)
# Out:
# <table><tbody><tr><td style="width: 20px; height: 20px; padding: 0px;border: 1px solid white; background-color: rgb(0, 0, 0);"></td><td style="width: 20px; height: 20px; padding: 0px;border: 1px solid white; background-color: rgb(0, 0, 0);"></td><td style="width: 20px; height: 20px; padding: 0px;border: 1px solid white; background-color: rgb(0, 0, 0);"></td></tr><tr><td style="width: 20px; height: 20px; padding: 0px;border: 1px solid white; background-color: rgb(0, 0, 0);"></td><td style="width: 20px; height: 20px; padding: 0px;border: 1px solid white; background-color: rgb(0, 0, 0);"></td><td style="width: 20px; height: 20px; padding: 0px;border: 1px solid white; background-color: rgb(0, 0, 0);"></td></tr><tr><td style="width: 20px; height: 20px; padding: 0px;border: 1px solid white; background-color: rgb(0, 0, 0);"></td><td style="width: 20px; height: 20px; padding: 0px;border: 1px solid white; background-color: rgb(0, 0, 0);"></td><td style="width: 20px; height: 20px; padding: 0px;border: 1px solid white; background-color: rgb(0, 255, 0);"></td></tr></tbody></table>

# %% [markdown]
# And this is so much fun that it's been added to `ipythonblocks`: one way is to use the `BlockGrid.animate` attribute.

# %%
grid = BlockGrid(3, 3)

previous_block = None

for block in grid.animate:
    block.green = 255
    
    if previous_block:
        previous_block.green = 0
    
    previous_block = block
# Out:
# <table><tbody><tr><td style="width: 20px; height: 20px; padding: 0px;border: 1px solid white; background-color: rgb(0, 0, 0);"></td><td style="width: 20px; height: 20px; padding: 0px;border: 1px solid white; background-color: rgb(0, 0, 0);"></td><td style="width: 20px; height: 20px; padding: 0px;border: 1px solid white; background-color: rgb(0, 0, 0);"></td></tr><tr><td style="width: 20px; height: 20px; padding: 0px;border: 1px solid white; background-color: rgb(0, 0, 0);"></td><td style="width: 20px; height: 20px; padding: 0px;border: 1px solid white; background-color: rgb(0, 0, 0);"></td><td style="width: 20px; height: 20px; padding: 0px;border: 1px solid white; background-color: rgb(0, 0, 0);"></td></tr><tr><td style="width: 20px; height: 20px; padding: 0px;border: 1px solid white; background-color: rgb(0, 0, 0);"></td><td style="width: 20px; height: 20px; padding: 0px;border: 1px solid white; background-color: rgb(0, 0, 0);"></td><td style="width: 20px; height: 20px; padding: 0px;border: 1px solid white; background-color: rgb(0, 255, 0);"></td></tr></tbody></table>

# %% [markdown]
# And another way, if not iterating over the grid, is to use the `BlockGrid.flash` method.

# %%
grid = BlockGrid(3, 3)

previous_block = None

indices = [[(0, 0), (0, 2), (2, 0), (2, 2)], [(0, 1), (1, 0), (1, 2), (2, 1)]] * 10

for ind in indices:
    for i in ind:
        grid[i[0], i[1]].green = 255
    
    grid.flash()
    
    for i in ind:
        grid[i[0], i[1]].green = 0
